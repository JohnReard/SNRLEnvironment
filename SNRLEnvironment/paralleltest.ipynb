# %%
import jax
import jax.numpy as jnp

devicecount = jax.device_count()
devices = jax.devices()


def addsclrs(x,y):
    return x+y

input1 = jnp.array([10])
input2 = jnp.array([10])
#input1=jnp.reshape(input1,(2,1))
#input2=jnp.reshape(input2,(2,1))
print("Dimensions:",input1.ndim, input2.ndim,"Shapes:",input1.shape, input2.shape)
print("input1:", input1.shape)
print("input2:", input2.shape)
print("GPU: ", devices)

#print(jax.pmap(addsclrs)(input1,input2))
# Out:
# Dimensions: 1 1 Shapes: (1,) (1,)
# input1: (1,)
# input2: (1,)
# GPU:  [CpuDevice(id=0)]
